# %% [markdown]
# # BUSINESS PROBLEM UNDERSTANDING

# %%
# Perform EDA
# Derive at least 5 business insights

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("Customers.csv")
df.head()
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB

# %%
df_1 = pd.read_csv("Products.csv")
df_1.head()
# Out:
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB

# %%
df_2 = pd.read_csv("Transactions.csv")
df_2
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 0        300.68  300.68
# 1        300.68  300.68
# 2        300.68  300.68
# 3        601.36  300.68
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price            1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB

# %%
# Join the "Customers" Dataframe with "Transcations" Dataframe on CustomerId

# %%
new_df = pd.merge(df,df_2, on = "CustomerID")

# %%
new_df
# Out:
#     CustomerID      CustomerName         Region  SignupDate TransactionID  \
# 0        C0001  Lawrence Carroll  South America  2022-07-10        T00015
# 1        C0001  Lawrence Carroll  South America  2022-07-10        T00932
# 2        C0001  Lawrence Carroll  South America  2022-07-10        T00085
# 3        C0001  Lawrence Carroll  South America  2022-07-10        T00445
# 4        C0001  Lawrence Carroll  South America  2022-07-10        T00436
# ..         ...               ...            ...         ...           ...
# 995      C0200       Kelly Cross           Asia  2023-06-11        T00518
# 996      C0200       Kelly Cross           Asia  2023-06-11        T00091
# 997      C0200       Kelly Cross           Asia  2023-06-11        T00731
# 998      C0200       Kelly Cross           Asia  2023-06-11        T00771
# 999      C0200       Kelly Cross           Asia  2023-06-11        T00889
#
#     ProductID      TransactionDate  Quantity  TotalValue   Price
# ...

# %%
# Join the "New" Dataframe with "Products" Dataframe on ProductId

# %%
new_df_1 = pd.merge(new_df,df_1,on='ProductID')

# %%
new_df_1
# Out:
#     CustomerID      CustomerName         Region  SignupDate TransactionID  \
# 0        C0001  Lawrence Carroll  South America  2022-07-10        T00015
# 1        C0001  Lawrence Carroll  South America  2022-07-10        T00932
# 2        C0001  Lawrence Carroll  South America  2022-07-10        T00085
# 3        C0001  Lawrence Carroll  South America  2022-07-10        T00445
# 4        C0001  Lawrence Carroll  South America  2022-07-10        T00436
# ..         ...               ...            ...         ...           ...
# 995      C0200       Kelly Cross           Asia  2023-06-11        T00518
# 996      C0200       Kelly Cross           Asia  2023-06-11        T00091
# 997      C0200       Kelly Cross           Asia  2023-06-11        T00731
# 998      C0200       Kelly Cross           Asia  2023-06-11        T00771
# 999      C0200       Kelly Cross           Asia  2023-06-11        T00889
#
#     ProductID      TransactionDate  Quantity  TotalValue  Price_x  \
# ...

# %%
# Drop the  "price_y" because we have the "Total_value" so need that seperate price

# %%
new_df_1.drop(columns=["Price_y"],inplace=True)

# %%
new_df_1
# Out:
#     CustomerID      CustomerName         Region  SignupDate TransactionID  \
# 0        C0001  Lawrence Carroll  South America  2022-07-10        T00015
# 1        C0001  Lawrence Carroll  South America  2022-07-10        T00932
# 2        C0001  Lawrence Carroll  South America  2022-07-10        T00085
# 3        C0001  Lawrence Carroll  South America  2022-07-10        T00445
# 4        C0001  Lawrence Carroll  South America  2022-07-10        T00436
# ..         ...               ...            ...         ...           ...
# 995      C0200       Kelly Cross           Asia  2023-06-11        T00518
# 996      C0200       Kelly Cross           Asia  2023-06-11        T00091
# 997      C0200       Kelly Cross           Asia  2023-06-11        T00731
# 998      C0200       Kelly Cross           Asia  2023-06-11        T00771
# 999      C0200       Kelly Cross           Asia  2023-06-11        T00889
#
#     ProductID      TransactionDate  Quantity  TotalValue  Price_x  \
# ...

# %%
new_df_1.rename(columns={'Price_x':'Price'},inplace=True)

# %%
new_df_1
# Out:
#     CustomerID      CustomerName         Region  SignupDate TransactionID  \
# 0        C0001  Lawrence Carroll  South America  2022-07-10        T00015
# 1        C0001  Lawrence Carroll  South America  2022-07-10        T00932
# 2        C0001  Lawrence Carroll  South America  2022-07-10        T00085
# 3        C0001  Lawrence Carroll  South America  2022-07-10        T00445
# 4        C0001  Lawrence Carroll  South America  2022-07-10        T00436
# ..         ...               ...            ...         ...           ...
# 995      C0200       Kelly Cross           Asia  2023-06-11        T00518
# 996      C0200       Kelly Cross           Asia  2023-06-11        T00091
# 997      C0200       Kelly Cross           Asia  2023-06-11        T00731
# 998      C0200       Kelly Cross           Asia  2023-06-11        T00771
# 999      C0200       Kelly Cross           Asia  2023-06-11        T00889
#
#     ProductID      TransactionDate  Quantity  TotalValue   Price  \
# ...

# %%
# This is the Final DatFrame

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# - **CustomerID** - Unique identifier for each customer
# - **CustomerName** - Name of the customer
# - **Region** - Continent where the customer resides
# - **SignupDate** - Date when the customer signed up
# - **TransactionID** -  Unique identifier for each transaction
# - **ProductID** - Unique identifier for each product
# - **TransactionDate** - Date of the transaction
# - **Quantity** - Quantity of the product purchased
# - **TotalValue** - Total value of the transaction
# - **Price** - Product price in USD
# - **ProductName** -  Name of the product
# - **Category** - Product category.

# %% [markdown]
# # Data Exploration

# %%
new_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   object
#  1   CustomerName     1000 non-null   object
#  2   Region           1000 non-null   object
#  3   SignupDate       1000 non-null   object
#  4   TransactionID    1000 non-null   object
#  5   ProductID        1000 non-null   object
#  6   TransactionDate  1000 non-null   object
#  7   Quantity         1000 non-null   int64
#  8   TotalValue       1000 non-null   float64
#  9   Price            1000 non-null   float64
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %% [markdown]
# observations
#
# - **SignupDate** is in wrong Data type need to convert
# - **TransactionDate** is in wrong Data type need to convert

# %%
new_df_1.isnull().sum()
# Out:
# CustomerID         0
# CustomerName       0
# Region             0
# SignupDate         0
# TransactionID      0
# ProductID          0
# TransactionDate    0
# Quantity           0
# TotalValue         0
# Price              0
# ProductName        0
# Category           0
# dtype: int64

# %%
new_df_1.duplicated().sum()
# Out:
# 0

# %%
# There are no Null and duplicated values

# %%
new_df_1["CustomerID"].nunique()
# Out:
# 199

# %%
new_df_1["CustomerName"].nunique()
# Out:
# 199

# %%
new_df_1["Region"].value_counts()
# Out:
# Region
# South America    304
# North America    244
# Europe           233
# Asia             218
# Name: count, dtype: int64

# %%
new_df_1["Quantity"].value_counts()
# Out:
# Quantity
# 4    261
# 3    254
# 2    245
# 1    239
# Name: count, dtype: int64

# %%
new_df_1["TotalValue"].describe()
# Out:
# count     999.000000
# mean      690.372012
# std       493.247703
# min        16.080000
# 25%       295.010000
# 50%       588.880000
# 75%      1011.660000
# max      1991.040000
# Name: TotalValue, dtype: float64

# %%
new_df_1["Category"].value_counts()
# Out:
# Category
# Books          270
# Electronics    254
# Home Decor     247
# Clothing       228
# Name: count, dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
new_df_1['TransactionDate'] = pd.to_datetime(new_df_1['TransactionDate'],format='mixed')
new_df_1['SignupDate'] = pd.to_datetime(new_df_1['SignupDate'],format='mixed')

# %%
new_df_1['TransactionMonth'] = new_df_1['TransactionDate'].dt.to_period('M')
new_df_1['SignupMonth'] = new_df_1['SignupDate'].dt.to_period('M')

# %%
new_df_1
# Out:
#     CustomerID      CustomerName         Region SignupDate TransactionID  \
# 0        C0001  Lawrence Carroll  South America 2022-07-10        T00015
# 1        C0001  Lawrence Carroll  South America 2022-07-10        T00932
# 2        C0001  Lawrence Carroll  South America 2022-07-10        T00085
# 3        C0001  Lawrence Carroll  South America 2022-07-10        T00445
# 4        C0001  Lawrence Carroll  South America 2022-07-10        T00436
# ..         ...               ...            ...        ...           ...
# 995      C0200       Kelly Cross           Asia 2023-06-11        T00518
# 996      C0200       Kelly Cross           Asia 2023-06-11        T00091
# 997      C0200       Kelly Cross           Asia 2023-06-11        T00731
# 998      C0200       Kelly Cross           Asia 2023-06-11        T00771
# 999      C0200       Kelly Cross           Asia 2023-06-11        T00889
#
#     ProductID     TransactionDate  Quantity  TotalValue   Price  \
# ...

# %%
new_df_1.sort_values(by='TransactionDate',ascending=True)
# Out:
#     CustomerID      CustomerName         Region SignupDate TransactionID  \
# 381      C0081   Kimberly Turner         Europe 2024-02-24        T00869
# 75       C0017     Jennifer King         Europe 2023-12-05        T00605
# 189      C0040   Michael Harrell           Asia 2022-03-07        T00154
# 757      C0154      Robert Sharp  North America 2024-10-27        T00845
# 795      C0161    Jessica Warren           Asia 2022-03-14        T00818
# ..         ...               ...            ...        ...           ...
# 938      C0188         Anna Ball  South America 2022-05-17        T00442
# 594      C0119   David Armstrong         Europe 2023-11-13        T00698
# 905      C0181  Alexander Barker  South America 2023-11-16        T00374
# 988      C0197  Christina Harvey         Europe 2023-03-21        T00951
# 494      C0101    Kelsey Roberts           Asia 2023-09-30        T00333
#
#     ProductID     TransactionDate  Quantity  TotalValue   Price  \
# ...

# %% [markdown]
# Observations:
#
# There is an error in the data, a person signup in 2024, but the transacation history shows he is shopping in 2023.

# %%
new_df_1[new_df_1["CustomerID"]== "C0081"]
# Out:
#     CustomerID     CustomerName  Region SignupDate TransactionID ProductID  \
# 381      C0081  Kimberly Turner  Europe 2024-02-24        T00869      P061
# 382      C0081  Kimberly Turner  Europe 2024-02-24        T00156      P068
# 383      C0081  Kimberly Turner  Europe 2024-02-24        T00676      P092
# 384      C0081  Kimberly Turner  Europe 2024-02-24        T00511      P030
# 385      C0081  Kimberly Turner  Europe 2024-02-24        T00388      P073
# 386      C0081  Kimberly Turner  Europe 2024-02-24        T00389      P006
#
#         TransactionDate  Quantity  TotalValue   Price  \
# 381 2023-12-30 15:29:12         2      313.92  156.96
# 382 2024-11-08 18:02:09         1      447.23  447.23
# 383 2024-09-04 02:55:21         4     1556.80  389.20
# 384 2024-05-26 05:56:36         3      833.58  277.86
# 385 2024-04-11 01:44:41         1       26.99   26.99
# 386 2024-01-20 04:23:56         3      363.96  121.32
#
# ...

# %%
# dropping the first index no of 381 becuase it is a wrong entrty
new_df_1.drop(index=[381],inplace=True)

# %% [markdown]
# # EDA

# %% [markdown]
# # Total Revenue

# %%
new_df_1["TotalValue"].sum()
# Out:
# 689681.64

# %%
monthly_sales = new_df_1.groupby("TransactionMonth")["TotalValue"].sum()
monthly_sales
# Out:
# TransactionMonth
# 2023-12     3455.60
# 2024-01    66376.39
# 2024-02    51459.27
# 2024-03    47828.73
# 2024-04    57519.06
# 2024-05    64527.74
# 2024-06    48771.18
# 2024-07    71366.39
# 2024-08    63436.74
# 2024-09    70603.75
# 2024-10    47063.22
# 2024-11    38224.37
# 2024-12    59049.20
# Freq: M, Name: TotalValue, dtype: float64

# %%
# Plotting monthly sales trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.values, marker='o', label='Sales per month')
# Defining consistent month order for x-axis
months = ['DEC', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV']
plt.xticks(range(len(months)), months)
plt.legend()
plt.title("Monthly Sales Trend", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Total value by Region

# %%
# Group data and calculate the sum
region_values = new_df_1.groupby("Region")["TotalValue"].sum()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=region_values.index, y=region_values.values, palette="viridis")

# Add labels and title
plt.xlabel("Region", fontsize=12)
plt.ylabel("Total Value", fontsize=12)
plt.title("Total Value by Region", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 5 Customers by Total Value

# %%
# Group data and calculate the sum
top_5_cust = new_df_1.groupby("CustomerName")["TotalValue"].sum()

# Sort and select the top 5 customers
top_5_cust = top_5_cust.sort_values(ascending=False).head()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_cust.values, y=top_5_cust.index, palette="coolwarm")

# Add labels and title
plt.xlabel("Total Value", fontsize=12)
plt.ylabel("Customer Name", fontsize=12)
plt.title("Top 5 Customers by Total Value", fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 5 Categories by Revenue

# %%
# Group data and calculate revenue on the basis of category
category_revenue = new_df_1.groupby('Category')['TotalValue'].sum().sort_values(ascending=False).head(5)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=category_revenue.values, y=category_revenue.index, palette="magma")

# Add labels and title
plt.xlabel("Revenue (Total Value)", fontsize=12)
plt.ylabel("Category", fontsize=12)
plt.title("Top 5 Categories by Revenue", fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 5 Produts by Revenue

# %%
# Group data and calculate revenue on the basis of product
product_revenue = new_df_1.groupby('ProductName')['TotalValue'].sum().sort_values(ascending=False).head(5)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=product_revenue.values, y=product_revenue.index, palette="crest")

# Add labels and title
plt.xlabel("Revenue (Total Value)", fontsize=12)
plt.ylabel("Product Name", fontsize=12)
plt.title("Top 5 Products by Revenue", fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
